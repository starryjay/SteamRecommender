# %%
#bleeble

# !pip3 install requests argparse
# !git clone https://github.com/FronkonGames/Steam-Games-Scraper

# %%
#bleeble
# !python SteamGamesScraper.py
# Out:
# [i 22:43:13] Steam Games Scraper 1.2.2 by Martin Bustos <fronkongames@gmail.com>.
# [i 22:43:13] New dataset created.
# [i 22:43:13] Requesting list of games from Steam.
# [i 22:43:17] Scraping ░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░ 0.0% (CTRL+C to exit).
# [i 22:43:21] Scraping ░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░ 0.0% (CTRL+C to exit).
# [i 22:43:25] Scraping ░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░ 0.0% (CTRL+C to exit).
# [i 22:43:27] Scraping ░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░ 0.0% (CTRL+C to exit).
# [i 22:43:29] Scraping ░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░ 0.0% (CTRL+C to exit).
# [i 22:43:31] Scraping ░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░ 0.0% (CTRL+C to exit).
# ...

# %%
# !python ConvertToCSV.py
# Out:
# Convert JSON to CSV 1.1.0 by Martin Bustos <fronkongames@gmail.com>.
# Loading dataset.
# Dataset with 277 games loaded.
# ░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░ 0.4%
# ░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░ 0.7%
# █░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░ 1.1%
# █░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░ 1.4%
# █░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░ 1.8%
# █░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░ 2.2%
# █░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░ 2.5%
# █░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░ 2.9%
# ██░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░ 3.2%
# ██░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░ 3.6%
# ██░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░ 4.0%
# ██░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░ 4.3%
# ██░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░ 4.7%
# ███░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░ 5.1%
# ███░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░ 5.4%
# ...

# %%
# !pip3 install pandas
# !pip3 install numpy
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np

# %%
games_raw = pd.read_csv('games.csv')

# %%
games_raw
# Out:
#       AppID                             Name  Release date Estimated owners  \
# 0   1818570                          Threes!   Feb 5, 2024        0 - 20000
# 1   2972040                          The Gap   Jun 4, 2024            0 - 0
# 2    997050               Hentai Like a Boss  Jan 24, 2019        0 - 20000
# 3   2097550                         Folktale   Sep 2, 2022        0 - 20000
# 4   2491690                    Shroom & Doom  Jul 21, 2023            0 - 0
# ..      ...                              ...           ...              ...
# 95   619600  Wrecked: Get Your Ship Together  Apr 13, 2017    20000 - 50000
# 96  1927060              Reversilly Playtest  Mar 17, 2022            0 - 0
# 97   808880                       MiniTracks  Nov 13, 2020        0 - 20000
# 98  1509050             Space of Retaliation  Jan 21, 2021        0 - 20000
# 99   407830                  Space Overlords   Mar 3, 2016        0 - 20000
#
#     Peak CCU  Required age  Price  DLC count  \
# ...
